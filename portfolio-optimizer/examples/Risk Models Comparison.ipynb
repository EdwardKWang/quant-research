# %%
"""Test different choices of risk models, which has best performance?

.. note::

    Some of the interfaces used here (custom hyper-parameter objects) are
    experimental and **are not covered by the semantic versioning agreement**,
    meaning that they could change without notice. In general, methods and
    interfaces shown in the examples are public and are protected
    under semantic versioning, but in this example that may not be the case.

.. note::

    The output of this example is currently (Cvxportfolio ``1.0.3``)
    not too easy to read; the ``__repr__`` method of a policy object
    with symbolic hyper-parameters is scheduled for improvement. It
    does work, though.

On the Dow Jones, daily trading from 2016 to today:
- diagonal risk model
- diagonal risk model with risk forecast error
- full covariance
- full covariance with risk forecast error
- ...

We test on a long-only portfolio and use automatic hyper-parameter
optimization to maximize the information ratio, in back-test,
versus the index ETF.
"""

import os
from pprint import pprint

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import cvxportfolio as cvx

from universes import DOW30 as UNIVERSE

# Index
INDEX = 'DIA'

# Times.
START = '2000-01-01'
END = None # today

# Leverage.
LEVERAGE_LIMIT = 1.

# Stock market simulator with default transaction and
# holding cost models.
simulator = cvx.StockMarketSimulator(UNIVERSE + [INDEX])

# Build benchmark.
all_in_index = pd.Series(
    0., index = simulator.market_data.returns.columns)
all_in_index[INDEX] = 1.
benchmark = cvx.FixedWeights(all_in_index)

# Define hyper-parameter objects.
# These will be included in the library in a future release.
class GammaTradeCoarse(cvx.RangeHyperParameter):
    """Transaction cost multiplier, coarse value range."""
    def __init__(self):
        super().__init__(
        values_range=np.arange(1, 11),
        current_value=1.)

class GammaTradeFine(cvx.RangeHyperParameter):
    """Transaction cost multiplier, fine value range."""
    def __init__(self):
        super().__init__(
        values_range=np.linspace(-1., 1., 51),
        current_value=0)

class GammaRiskCoarse(cvx.RangeHyperParameter):
    """Risk term multiplier, coarse value range."""
    def __init__(self):
        super().__init__(
        values_range=np.arange(1, 21),
        current_value=1.)

class GammaRiskFine(cvx.RangeHyperParameter):
    """Risk term multiplier, fine value range."""
    def __init__(self):
        super().__init__(
        values_range=np.linspace(-1., 1., 51),
        current_value=0)

class Kappa(cvx.RangeHyperParameter):
    """Risk forecast error multiplier, fine value range."""
    def __init__(self):
        super().__init__(
        values_range=np.linspace(0., 0.5),
        current_value=0)


# We test these risk models, with symbolic hyper-parameters.
base_risk_models = [cvx.DiagonalCovariance(), cvx.FullCovariance()]
base_risk_models += [
    cvx.FactorModelCovariance(num_factors=num_factors)
    for num_factors in [1, 2, 5, 10]
]

# with hyper-parameters
RISK_MODELS = [
    (GammaRiskCoarse() + GammaRiskFine()) * base_risk_model
    for base_risk_model in base_risk_models
]

# with risk forecast error
RISK_MODELS += [
    (GammaRiskCoarse() + GammaRiskFine()) * (
    base_risk_model + Kappa() * cvx.RiskForecastError())
    for base_risk_model in base_risk_models
]

results = {}

for risk_model in RISK_MODELS:
    print('Testing risk model:')
    print(risk_model)

    results[repr(risk_model)] = {}
    current_result = results[repr(risk_model)]

    # Build policy.
    policy = cvx.SinglePeriodOpt(
        objective = cvx.ReturnsForecast()
            - (GammaTradeCoarse() + GammaTradeFine()
                ) * cvx.StocksTransactionCost()
            - risk_model,
        constraints=[cvx.LongOnly(), cvx.LeverageLimit(LEVERAGE_LIMIT)],
        benchmark=benchmark,
        solver='CLARABEL')

    # Optimize HPs.
    simulator.optimize_hyperparameters(
        policy, start_time=START, end_time=END,
        objective='information_ratio')

    print('Policy with optimized hyper-parameters:')
    print(policy)
    current_result['Optimized policy'] = repr(policy)

    # Run back-test with optimized HPs.
    optimized_result = simulator.backtest(
        policy, start_time=START, end_time=END)

    print('Back-test result with optimized hyper-parameters:')
    print(optimized_result)
    current_result['Optimized result'] = optimized_result

pprint(results)
# Out:
# Updating data..............
# YahooFinance("HD") has dubious total open-to-open returns for timestamps: DatetimeIndex(['1983-03-18 14:30:00+00:00'], dtype='datetime64[ns, UTC]', freq=None)
# .......
# YahooFinance("MCD") has dubious total open-to-open returns for timestamps: DatetimeIndex(['1969-07-09 13:30:00+00:00'], dtype='datetime64[ns, UTC]', freq=None)
# ......
# YahooFinance("TRV") has dubious total open-to-open returns for timestamps: DatetimeIndex(['1986-06-12 13:30:00+00:00'], dtype='datetime64[ns, UTC]', freq=None)
# ....
# Testing risk model:
# + GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=0.0) * DiagonalCovariance(sigma_squares=HistoricalVariance(half_life=inf, rolling=inf, kelly=True))
# iteration 0
# Current objective:
# 0.35348582566780506
# iteration 1
# Current objective:
# 0.3610703508995951
# iteration 2
# Current objective:
# 0.3641256382552266
# iteration 3
# Current objective:
# 0.3666111591832698
# iteration 4
# Current objective:
# 0.36821041140562216
# iteration 5
# Current objective:
# 0.36903188080496596
# iteration 6
# Current objective:
# 0.3692325913469791
# iteration 7
# Current objective:
# 0.36932496634064016
# iteration 8
# Current objective:
# 0.3694567434759379
# iteration 9
# Current objective:
# 0.36994869627624727
# iteration 10
# Current objective:
# 0.3708319994921935
# iteration 11
# Current objective:
# 0.3712992531818
# iteration 12
# Current objective:
# 0.3719466613861964
# iteration 13
# Current objective:
# 0.3721643502995488
# iteration 14
# Current objective:
# 0.37224633247320404
# Policy with optimized hyper-parameters:
# SinglePeriodOpt(objective=ReturnsForecast(r_hat=HistoricalMeanReturn(half_life=inf, rolling=inf), decay=1.0)- GammaTradeCoarse(current_value=1) + GammaTradeFine(current_value=-0.31999999999999995) * StocksTransactionCost(a=0.0, b=1.0, market_volumes=VolumeHatOrRealized(volume_hat=HistoricalMeanVolume(half_life=inf, rolling=Timedelta('365 days 05:45:36'))), sigma=HistoricalStandardDeviation(half_life=inf, rolling=Timedelta('365 days 05:45:36'), kelly=True), exponent=1.5, pershare_cost=0.005)- GammaRiskCoarse(current_value=2) + GammaRiskFine(current_value=-0.12) * DiagonalCovariance(sigma_squares=HistoricalVariance(half_life=inf, rolling=inf, kelly=True)) + CashReturn(), constraints=[LongOnly(applies_to_cash=False), LeverageLimit(limit=1.0)], benchmark=FixedWeights(target_weights=pd.Series(hash_values=dc587c9978, hash_index=5f42a8cf48)), cvxpy_kwargs={'solver': 'CLARABEL'})
# Back-test result with optimized hyper-parameters:
#
# #################################################################
# Universe size                                                  32
# Initial timestamp                       2000-01-03 14:30:00+00:00
# Final timestamp                         2024-03-19 13:30:00+00:00
# Number of periods                                            6091
# Initial value (USDOLLAR)                                1.000e+06
# Final value (USDOLLAR)                                  1.637e+07
# Profit (USDOLLAR)                                       1.537e+07
#
# Avg. return (annualized)                                    15.3%
# Volatility (annualized)                                     27.4%
# Avg. excess return (annualized)                             13.5%
# Avg. active return (annualized)                              6.5%
# Excess volatility (annualized)                              27.4%
# Active volatility (annualized)                              17.5%
#
# Avg. growth rate (annualized)                               11.6%
# Avg. excess growth rate (annualized)                         9.8%
# Avg. active growth rate (annualized)                         5.0%
#
# Avg. StocksTransactionCost                                    0bp
# Max. StocksTransactionCost                                    8bp
# Avg. StocksHoldingCost                                        0bp
# Max. StocksHoldingCost                                        0bp
#
# Sharpe ratio                                                 0.49
# Information ratio                                            0.37
#
# Avg. drawdown                                              -21.0%
# Min. drawdown                                              -73.1%
# Avg. leverage                                              100.0%
# Max. leverage                                              100.1%
# Avg. turnover                                                0.0%
# Max. turnover                                               50.0%
#
# Avg. policy time                                           0.006s
# Avg. simulator time                                        0.006s
# Total time                                                71.435s
# #################################################################
#
# Testing risk model:
# + GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=0.0) * FullCovariance(Sigma=HistoricalFactorizedCovariance(half_life=inf, rolling=inf, kelly=True))
# iteration 0
# Current objective:
# 0.37667181309721554
# iteration 1
# Current objective:
# 0.3791824192394068
# iteration 2
# Current objective:
# 0.382705548411342
# iteration 3
# Current objective:
# 0.3859418733187389
# iteration 4
# Current objective:
# 0.38823711605897193
# iteration 5
# Current objective:
# 0.3906735936906598
# iteration 6
# Current objective:
# 0.39257489098041815
# iteration 7
# Current objective:
# 0.393813463312111
# iteration 8
# Current objective:
# 0.39484131527163113
# iteration 9
# Current objective:
# 0.3963315573793384
# iteration 10
# Current objective:
# 0.3980806765101804
# iteration 11
# Current objective:
# 0.4000044688021781
# iteration 12
# Current objective:
# 0.4010686820685917
# iteration 13
# Current objective:
# 0.4018721193430353
# iteration 14
# Current objective:
# 0.4021113615255621
# Policy with optimized hyper-parameters:
# SinglePeriodOpt(objective=ReturnsForecast(r_hat=HistoricalMeanReturn(half_life=inf, rolling=inf), decay=1.0)- GammaTradeCoarse(current_value=1) + GammaTradeFine(current_value=-0.31999999999999995) * StocksTransactionCost(a=0.0, b=1.0, market_volumes=VolumeHatOrRealized(volume_hat=HistoricalMeanVolume(half_life=inf, rolling=Timedelta('365 days 05:45:36'))), sigma=HistoricalStandardDeviation(half_life=inf, rolling=Timedelta('365 days 05:45:36'), kelly=True), exponent=1.5, pershare_cost=0.005)- GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=-0.24) * FullCovariance(Sigma=HistoricalFactorizedCovariance(half_life=inf, rolling=inf, kelly=True)) + CashReturn(), constraints=[LongOnly(applies_to_cash=False), LeverageLimit(limit=1.0)], benchmark=FixedWeights(target_weights=pd.Series(hash_values=dc587c9978, hash_index=5f42a8cf48)), cvxpy_kwargs={'solver': 'CLARABEL'})
# Back-test result with optimized hyper-parameters:
#
# #################################################################
# Universe size                                                  32
# Initial timestamp                       2000-01-03 14:30:00+00:00
# Final timestamp                         2024-03-19 13:30:00+00:00
# Number of periods                                            6091
# Initial value (USDOLLAR)                                1.000e+06
# Final value (USDOLLAR)                                  2.757e+07
# Profit (USDOLLAR)                                       2.657e+07
#
# Avg. return (annualized)                                    20.9%
# Volatility (annualized)                                     38.0%
# Avg. excess return (annualized)                             19.2%
# Avg. active return (annualized)                             12.1%
# Excess volatility (annualized)                              38.0%
# Active volatility (annualized)                              30.1%
#
# Avg. growth rate (annualized)                               13.7%
# Avg. excess growth rate (annualized)                        11.9%
# Avg. active growth rate (annualized)                         7.6%
#
# Avg. StocksTransactionCost                                    0bp
# Max. StocksTransactionCost                                   16bp
# Avg. StocksHoldingCost                                        0bp
# Max. StocksHoldingCost                                        0bp
#
# Sharpe ratio                                                 0.50
# Information ratio                                            0.40
#
# Avg. drawdown                                              -25.5%
# Min. drawdown                                              -88.4%
# Avg. leverage                                              100.0%
# Max. leverage                                              100.2%
# Avg. turnover                                                0.0%
# Max. turnover                                               50.0%
#
# Avg. policy time                                           0.007s
# Avg. simulator time                                        0.007s
# Total time                                                87.544s
# #################################################################
#
# Testing risk model:
# + GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=0.0) * FactorModelCovariance(Sigma=HistoricalFactorizedCovariance(half_life=inf, rolling=inf, kelly=True), num_factors=1)
# iteration 0
# Current objective:
# 0.3877888676960643
# iteration 1
# Current objective:
# 0.388704516614901
# iteration 2
# Current objective:
# 0.3897788163365611
# iteration 3
# Current objective:
# 0.3907341811961323
# iteration 4
# Current objective:
# 0.39229337872127956
# iteration 5
# Current objective:
# 0.39397822236860497
# iteration 6
# Current objective:
# 0.39540794279389496
# iteration 7
# Current objective:
# 0.3961166499793349
# iteration 8
# Current objective:
# 0.3972206422993084
# iteration 9
# Current objective:
# 0.3977491765384303
# iteration 10
# Current objective:
# 0.39787187807562313
# iteration 11
# Current objective:
# 0.4000728205290706
# Policy with optimized hyper-parameters:
# SinglePeriodOpt(objective=ReturnsForecast(r_hat=HistoricalMeanReturn(half_life=inf, rolling=inf), decay=1.0)- GammaTradeCoarse(current_value=1) + GammaTradeFine(current_value=-0.28) * StocksTransactionCost(a=0.0, b=1.0, market_volumes=VolumeHatOrRealized(volume_hat=HistoricalMeanVolume(half_life=inf, rolling=Timedelta('365 days 05:45:36'))), sigma=HistoricalStandardDeviation(half_life=inf, rolling=Timedelta('365 days 05:45:36'), kelly=True), exponent=1.5, pershare_cost=0.005)- GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=-0.16000000000000003) * FactorModelCovariance(Sigma=HistoricalFactorizedCovariance(half_life=inf, rolling=inf, kelly=True), num_factors=1) + CashReturn(), constraints=[LongOnly(applies_to_cash=False), LeverageLimit(limit=1.0)], benchmark=FixedWeights(target_weights=pd.Series(hash_values=dc587c9978, hash_index=5f42a8cf48)), cvxpy_kwargs={'solver': 'CLARABEL'})
# Back-test result with optimized hyper-parameters:
#
# #################################################################
# Universe size                                                  32
# Initial timestamp                       2000-01-03 14:30:00+00:00
# Final timestamp                         2024-03-19 13:30:00+00:00
# Number of periods                                            6091
# Initial value (USDOLLAR)                                1.000e+06
# Final value (USDOLLAR)                                  2.739e+07
# Profit (USDOLLAR)                                       2.639e+07
#
# Avg. return (annualized)                                    20.9%
# Volatility (annualized)                                     38.1%
# Avg. excess return (annualized)                             19.2%
# Avg. active return (annualized)                             12.1%
# Excess volatility (annualized)                              38.1%
# Active volatility (annualized)                              30.2%
#
# Avg. growth rate (annualized)                               13.7%
# Avg. excess growth rate (annualized)                        11.9%
# Avg. active growth rate (annualized)                         7.5%
#
# Avg. StocksTransactionCost                                    0bp
# Max. StocksTransactionCost                                   15bp
# Avg. StocksHoldingCost                                        0bp
# Max. StocksHoldingCost                                        0bp
#
# Sharpe ratio                                                 0.50
# Information ratio                                            0.40
#
# Avg. drawdown                                              -24.9%
# Min. drawdown                                              -88.6%
# Avg. leverage                                              100.0%
# Max. leverage                                              100.2%
# Avg. turnover                                                0.0%
# Max. turnover                                               50.0%
#
# Avg. policy time                                           0.005s
# Avg. simulator time                                        0.006s
# Total time                                                70.565s
# #################################################################
#
# Testing risk model:
# + GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=0.0) * FactorModelCovariance(Sigma=HistoricalFactorizedCovariance(half_life=inf, rolling=inf, kelly=True), num_factors=2)
# iteration 0
# Current objective:
# 0.38524704804903986
# iteration 1
# Current objective:
# 0.3887240238500103
# iteration 2
# Current objective:
# 0.39157972754431297
# iteration 3
# Current objective:
# 0.3946133813262917
# iteration 4
# Current objective:
# 0.39651924225019197
# iteration 5
# Current objective:
# 0.3992872146642115
# iteration 6
# Current objective:
# 0.4018059116705537
# iteration 7
# Current objective:
# 0.4037018967405183
# iteration 8
# Current objective:
# 0.4054905949789862
# iteration 9
# Current objective:
# 0.4068020604183994
# iteration 10
# Current objective:
# 0.40876651094563093
# iteration 11
# Current objective:
# 0.41086387143566144
# iteration 12
# Current objective:
# 0.41289222543713405
# iteration 13
# Current objective:
# 0.41555962873740543
# iteration 14
# Current objective:
# 0.41755395929917144
# iteration 15
# Current objective:
# 0.41806068167527777
# iteration 16
# Current objective:
# 0.4196450296502609
# iteration 17
# Current objective:
# 0.420107226407662
# iteration 18
# Current objective:
# 0.420939931997505
# iteration 19
# Current objective:
# 0.42136375618883887
# iteration 20
# Current objective:
# 0.42170611526317936
# iteration 21
# Current objective:
# 0.42254858352214675
# Policy with optimized hyper-parameters:
# SinglePeriodOpt(objective=ReturnsForecast(r_hat=HistoricalMeanReturn(half_life=inf, rolling=inf), decay=1.0)- GammaTradeCoarse(current_value=1) + GammaTradeFine(current_value=-0.48) * StocksTransactionCost(a=0.0, b=1.0, market_volumes=VolumeHatOrRealized(volume_hat=HistoricalMeanVolume(half_life=inf, rolling=Timedelta('365 days 05:45:36'))), sigma=HistoricalStandardDeviation(half_life=inf, rolling=Timedelta('365 days 05:45:36'), kelly=True), exponent=1.5, pershare_cost=0.005)- GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=-0.36) * FactorModelCovariance(Sigma=HistoricalFactorizedCovariance(half_life=inf, rolling=inf, kelly=True), num_factors=2) + CashReturn(), constraints=[LongOnly(applies_to_cash=False), LeverageLimit(limit=1.0)], benchmark=FixedWeights(target_weights=pd.Series(hash_values=dc587c9978, hash_index=5f42a8cf48)), cvxpy_kwargs={'solver': 'CLARABEL'})
# Back-test result with optimized hyper-parameters:
#
# #################################################################
# Universe size                                                  32
# Initial timestamp                       2000-01-03 14:30:00+00:00
# Final timestamp                         2024-03-19 13:30:00+00:00
# Number of periods                                            6091
# Initial value (USDOLLAR)                                1.000e+06
# Final value (USDOLLAR)                                  3.429e+07
# Profit (USDOLLAR)                                       3.329e+07
#
# Avg. return (annualized)                                    22.8%
# Volatility (annualized)                                     40.6%
# Avg. excess return (annualized)                             21.1%
# Avg. active return (annualized)                             14.0%
# Excess volatility (annualized)                              40.6%
# Active volatility (annualized)                              33.1%
#
# Avg. growth rate (annualized)                               14.6%
# Avg. excess growth rate (annualized)                        12.8%
# Avg. active growth rate (annualized)                         8.5%
#
# Avg. StocksTransactionCost                                    0bp
# Max. StocksTransactionCost                                   20bp
# Avg. StocksHoldingCost                                        0bp
# Max. StocksHoldingCost                                        0bp
#
# Sharpe ratio                                                 0.52
# Information ratio                                            0.42
#
# Avg. drawdown                                              -24.3%
# Min. drawdown                                              -90.0%
# Avg. leverage                                              100.0%
# Max. leverage                                              100.2%
# Avg. turnover                                                0.0%
# Max. turnover                                               50.0%
#
# Avg. policy time                                           0.005s
# Avg. simulator time                                        0.006s
# Total time                                                69.191s
# #################################################################
#
# Testing risk model:
# + GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=0.0) * FactorModelCovariance(Sigma=HistoricalFactorizedCovariance(half_life=inf, rolling=inf, kelly=True), num_factors=5)
# iteration 0
# Current objective:
# 0.3757870883264659
# iteration 1
# Current objective:
# 0.37846179861664203
# iteration 2
# Current objective:
# 0.38107320613929957
# iteration 3
# Current objective:
# 0.38356832971577026
# iteration 4
# Current objective:
# 0.3856824657553704
# iteration 5
# Current objective:
# 0.3875940320469696
# iteration 6
# Current objective:
# 0.3900678964697694
# iteration 7
# Current objective:
# 0.3914088626967203
# iteration 8
# Current objective:
# 0.3927269101977802
# iteration 9
# Current objective:
# 0.39375225772366346
# iteration 10
# Current objective:
# 0.3951058702138844
# iteration 11
# Current objective:
# 0.3966011187592735
# iteration 12
# Current objective:
# 0.3987760657513492
# iteration 13
# Current objective:
# 0.40046970072462235
# iteration 14
# Current objective:
# 0.4018810477911282
# Policy with optimized hyper-parameters:
# SinglePeriodOpt(objective=ReturnsForecast(r_hat=HistoricalMeanReturn(half_life=inf, rolling=inf), decay=1.0)- GammaTradeCoarse(current_value=1) + GammaTradeFine(current_value=-0.31999999999999995) * StocksTransactionCost(a=0.0, b=1.0, market_volumes=VolumeHatOrRealized(volume_hat=HistoricalMeanVolume(half_life=inf, rolling=Timedelta('365 days 05:45:36'))), sigma=HistoricalStandardDeviation(half_life=inf, rolling=Timedelta('365 days 05:45:36'), kelly=True), exponent=1.5, pershare_cost=0.005)- GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=-0.24) * FactorModelCovariance(Sigma=HistoricalFactorizedCovariance(half_life=inf, rolling=inf, kelly=True), num_factors=5) + CashReturn(), constraints=[LongOnly(applies_to_cash=False), LeverageLimit(limit=1.0)], benchmark=FixedWeights(target_weights=pd.Series(hash_values=dc587c9978, hash_index=5f42a8cf48)), cvxpy_kwargs={'solver': 'CLARABEL'})
# Back-test result with optimized hyper-parameters:
#
# #################################################################
# Universe size                                                  32
# Initial timestamp                       2000-01-03 14:30:00+00:00
# Final timestamp                         2024-03-19 13:30:00+00:00
# Number of periods                                            6091
# Initial value (USDOLLAR)                                1.000e+06
# Final value (USDOLLAR)                                  2.740e+07
# Profit (USDOLLAR)                                       2.640e+07
#
# Avg. return (annualized)                                    20.8%
# Volatility (annualized)                                     37.8%
# Avg. excess return (annualized)                             19.1%
# Avg. active return (annualized)                             12.0%
# Excess volatility (annualized)                              37.8%
# Active volatility (annualized)                              29.9%
#
# Avg. growth rate (annualized)                               13.7%
# Avg. excess growth rate (annualized)                        11.9%
# Avg. active growth rate (annualized)                         7.6%
#
# Avg. StocksTransactionCost                                    0bp
# Max. StocksTransactionCost                                   16bp
# Avg. StocksHoldingCost                                        0bp
# Max. StocksHoldingCost                                        0bp
#
# Sharpe ratio                                                 0.50
# Information ratio                                            0.40
#
# Avg. drawdown                                              -25.5%
# Min. drawdown                                              -87.9%
# Avg. leverage                                              100.0%
# Max. leverage                                              100.2%
# Avg. turnover                                                0.0%
# Max. turnover                                               50.0%
#
# Avg. policy time                                           0.006s
# Avg. simulator time                                        0.178s
# Total time                                              1116.329s
# #################################################################
#
# Testing risk model:
# + GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=0.0) * FactorModelCovariance(Sigma=HistoricalFactorizedCovariance(half_life=inf, rolling=inf, kelly=True), num_factors=10)
# iteration 0
# Current objective:
# 0.37695613067920414
# iteration 1
# Current objective:
# 0.37950288561936957
# iteration 2
# Current objective:
# 0.38290859590097887
# iteration 3
# Current objective:
# 0.38634440375087764
# iteration 4
# Current objective:
# 0.388842101626867
# iteration 5
# Current objective:
# 0.3907250360719418
# iteration 6
# Current objective:
# 0.39293867117075987
# iteration 7
# Current objective:
# 0.39426743176858026
# iteration 8
# Current objective:
# 0.39526116205508127
# iteration 9
# Current objective:
# 0.3966525800159895
# iteration 10
# Current objective:
# 0.3987627156807746
# iteration 11
# Current objective:
# 0.401268203623237
# iteration 12
# Current objective:
# 0.4030255297351103
# iteration 13
# Current objective:
# 0.4039493015359527
# iteration 14
# Current objective:
# 0.4043637431185113
# Policy with optimized hyper-parameters:
# SinglePeriodOpt(objective=ReturnsForecast(r_hat=HistoricalMeanReturn(half_life=inf, rolling=inf), decay=1.0)- GammaTradeCoarse(current_value=1) + GammaTradeFine(current_value=-0.31999999999999995) * StocksTransactionCost(a=0.0, b=1.0, market_volumes=VolumeHatOrRealized(volume_hat=HistoricalMeanVolume(half_life=inf, rolling=Timedelta('365 days 05:45:36'))), sigma=HistoricalStandardDeviation(half_life=inf, rolling=Timedelta('365 days 05:45:36'), kelly=True), exponent=1.5, pershare_cost=0.005)- GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=-0.24) * FactorModelCovariance(Sigma=HistoricalFactorizedCovariance(half_life=inf, rolling=inf, kelly=True), num_factors=10) + CashReturn(), constraints=[LongOnly(applies_to_cash=False), LeverageLimit(limit=1.0)], benchmark=FixedWeights(target_weights=pd.Series(hash_values=dc587c9978, hash_index=5f42a8cf48)), cvxpy_kwargs={'solver': 'CLARABEL'})
# Back-test result with optimized hyper-parameters:
#
# #################################################################
# Universe size                                                  32
# Initial timestamp                       2000-01-03 14:30:00+00:00
# Final timestamp                         2024-03-19 13:30:00+00:00
# Number of periods                                            6091
# Initial value (USDOLLAR)                                1.000e+06
# Final value (USDOLLAR)                                  2.802e+07
# Profit (USDOLLAR)                                       2.702e+07
#
# Avg. return (annualized)                                    21.0%
# Volatility (annualized)                                     38.0%
# Avg. excess return (annualized)                             19.2%
# Avg. active return (annualized)                             12.2%
# Excess volatility (annualized)                              38.0%
# Active volatility (annualized)                              30.1%
#
# Avg. growth rate (annualized)                               13.8%
# Avg. excess growth rate (annualized)                        12.0%
# Avg. active growth rate (annualized)                         7.7%
#
# Avg. StocksTransactionCost                                    0bp
# Max. StocksTransactionCost                                   16bp
# Avg. StocksHoldingCost                                        0bp
# Max. StocksHoldingCost                                        0bp
#
# Sharpe ratio                                                 0.51
# Information ratio                                            0.40
#
# Avg. drawdown                                              -25.4%
# Min. drawdown                                              -88.3%
# Avg. leverage                                              100.0%
# Max. leverage                                              100.2%
# Avg. turnover                                                0.0%
# Max. turnover                                               50.0%
#
# Avg. policy time                                           0.006s
# Avg. simulator time                                        0.010s
# Total time                                                93.861s
# #################################################################
#
# Testing risk model:
# + GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=0.0) * DiagonalCovariance(sigma_squares=HistoricalVariance(half_life=inf, rolling=inf, kelly=True))+ GammaRiskCoarse(current_value=1) + GammaRiskFine(current_value=0.0) * Kappa(current_value=0.0) * RiskForecastError(sigma_squares=HistoricalVariance(half_life=inf, rolling=inf, kelly=True))
# iteration 0
# Current objective:
# 0.3534750741603271
# iteration 1
# Current objective:
# 0.3610702260949635
# iteration 2
# Current objective:
# 0.3641203849620956
# iteration 3
# Current objective:
# 0.36661717410441963
# iteration 4
# Current objective:
# 0.3682102691649593
# iteration 5
# Current objective:
# 0.36902009415691944
# iteration 6
# Current objective:
# 0.3692388844019896
# iteration 7
# Current objective:
# 0.3693240454225705
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 139
#     129 policy = cvx.SinglePeriodOpt(
#     130     objective = cvx.ReturnsForecast()
#     131         - (GammaTradeCoarse() + GammaTradeFine()
#    (...)
#     135     benchmark=benchmark,
#     136     solver='CLARABEL')
#     138 # Optimize HPs.
# --> 139 simulator.optimize_hyperparameters(
#     140     policy, start_time=START, end_time=END,
#     141     objective='information_ratio')
#     143 print('Policy with optimized hyper-parameters:')
#     144 print(policy)
#
# File ~/.pyenv/versions/3.12.2/envs/rsch/lib/python3.12/site-packages/cvxportfolio/simulator.py:530, in MarketSimulator.optimize_hyperparameters(self, policy, start_time, end_time, initial_value, h, objective, parallel)
#     527 if len(test_policies) == 0:
#     528     break
# --> 530 results_partial = self.backtest_many(test_policies,
#     531     start_time=start_time, end_time=end_time,
#     532     initial_value=initial_value,
#     533     h=h, parallel=parallel)
#     535 objectives_partial = [getattr(res, objective)
#     536     for res in results_partial]
#     538 for pol, obje in zip(test_policies, objectives_partial):
#
# File ~/.pyenv/versions/3.12.2/envs/rsch/lib/python3.12/site-packages/cvxportfolio/simulator.py:696, in MarketSimulator.backtest_many(self, policies, start_time, end_time, initial_value, h, parallel)
#     694 else:
#     695     with Pool(initializer=_mp_init, initargs=(Lock(),)) as p:
# --> 696         result = p.starmap(self._worker, zip_args)
#     698 return list(result)
#
# File ~/.pyenv/versions/3.12.2/envs/rsch/lib/python3.12/site-packages/multiprocess/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File ~/.pyenv/versions/3.12.2/envs/rsch/lib/python3.12/site-packages/multiprocess/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/.pyenv/versions/3.12.2/envs/rsch/lib/python3.12/site-packages/multiprocess/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
